# %% [markdown]
# <a href="https://colab.research.google.com/github/Ashish1999Kumar/Deep-learning/blob/master/postman.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
# !ls
import pandas as pd
# Out:
# sample_data

# %%
from google.colab import files

# %%
uploaded = files.upload()
# Out:
#      <input type="file" id="files-50ae9ec6-2d60-473e-9d1d-c8dd4dbf0d9e" name="files[]" multiple disabled />
#      <output id="result-50ae9ec6-2d60-473e-9d1d-c8dd4dbf0d9e">
#       Upload widget is only available when the cell has been executed in the
#       current browser session. Please rerun this cell to enable.
#       </output>
#       <script src="/nbextensions/google.colab/files.js"></script>
# Saving date.csv to date.csv
# Saving sales_data.csv to sales_data.csv

# %%
# !ls
# Out:
# date.csv  sales_data.csv  sample_data

# %%
# Out:
# rm: cannot remove 'open?id=1yWCS_54VsT1ksuCX137kdeUJ9HQ_ImMc': No such file or directory

# %%
# !ls
# Out:
# date.csv  sales_data.csv  sample_data

# %%
df=pd.read_csv('sales_data.csv')

# %%
df.head()
# Out:
#   transaction id product id  ... customer id  transaction country
# 0         536365     85123A  ...     17850.0       United Kingdom
# 1         536365      71053  ...     17850.0       United Kingdom
# 2         536365     84406B  ...     17850.0       United Kingdom
# 3         536365     84029G  ...     17850.0       United Kingdom
# 4         536365     84029E  ...     17850.0       United Kingdom
#
# [5 rows x 8 columns]

# %%
df1=df.drop(['product description'],axis=1)

# %%
df1
# Out:
#        transaction id product id  ...  customer id transaction country
# 0              536365     85123A  ...      17850.0      United Kingdom
# 1              536365      71053  ...      17850.0      United Kingdom
# 2              536365     84406B  ...      17850.0      United Kingdom
# 3              536365     84029G  ...      17850.0      United Kingdom
# 4              536365     84029E  ...      17850.0      United Kingdom
# 5              536365      22752  ...      17850.0      United Kingdom
# 6              536365      21730  ...      17850.0      United Kingdom
# 7              536366      22633  ...      17850.0      United Kingdom
# 8              536366      22632  ...      17850.0      United Kingdom
# 9              536367      84879  ...      13047.0      United Kingdom
# 10             536367      22745  ...      13047.0      United Kingdom
# 11             536367      22748  ...      13047.0      United Kingdom
# 12             536367      22749  ...      13047.0      United Kingdom
# 13             536367      22310  ...      13047.0      United Kingdom
# 14             536367      84969  ...      13047.0      United Kingdom
# 15             536367      22623  ...      13047.0      United Kingdom
# 16             536367      22622  ...      13047.0      United Kingdom
# 17             536367      21754  ...      13047.0      United Kingdom
# 18             536367      21755  ...      13047.0      United Kingdom
# 19             536367      21777  ...      13047.0      United Kingdom
# 20             536367      48187  ...      13047.0      United Kingdom
# 21             536368      22960  ...      13047.0      United Kingdom
# 22             536368      22913  ...      13047.0      United Kingdom
# 23             536368      22912  ...      13047.0      United Kingdom
# 24             536368      22914  ...      13047.0      United Kingdom
# 25             536369      21756  ...      13047.0      United Kingdom
# 26             536370      22728  ...      12583.0              France
# 27             536370      22727  ...      12583.0              France
# 28             536370      22726  ...      12583.0              France
# 29             536370      21724  ...      12583.0              France
# ...               ...        ...  ...          ...                 ...
# 541879         581585      22726  ...      15804.0      United Kingdom
# 541880         581585      22727  ...      15804.0      United Kingdom
# 541881         581585      16016  ...      15804.0      United Kingdom
# 541882         581585      21916  ...      15804.0      United Kingdom
# 541883         581585      84692  ...      15804.0      United Kingdom
# 541884         581585      84946  ...      15804.0      United Kingdom
# 541885         581585      21684  ...      15804.0      United Kingdom
# 541886         581585      22398  ...      15804.0      United Kingdom
# 541887         581585      23328  ...      15804.0      United Kingdom
# 541888         581585      23145  ...      15804.0      United Kingdom
# 541889         581585      22466  ...      15804.0      United Kingdom
# 541890         581586      22061  ...      13113.0      United Kingdom
# 541891         581586      23275  ...      13113.0      United Kingdom
# 541892         581586      21217  ...      13113.0      United Kingdom
# 541893         581586      20685  ...      13113.0      United Kingdom
# 541894         581587      22631  ...      12680.0              France
# 541895         581587      22556  ...      12680.0              France
# 541896         581587      22555  ...      12680.0              France
# 541897         581587      22728  ...      12680.0              France
# 541898         581587      22727  ...      12680.0              France
# 541899         581587      22726  ...      12680.0              France
# 541900         581587      22730  ...      12680.0              France
# 541901         581587      22367  ...      12680.0              France
# 541902         581587      22629  ...      12680.0              France
# 541903         581587      23256  ...      12680.0              France
# 541904         581587      22613  ...      12680.0              France
# 541905         581587      22899  ...      12680.0              France
# 541906         581587      23254  ...      12680.0              France
# 541907         581587      23255  ...      12680.0              France
# 541908         581587      22138  ...      12680.0              France
#
# [541909 rows x 7 columns]

# %%
date=pd.read_csv('date.csv')

# %%
df1['timestamp']=df1['transaction timestamp']
df2=df1.drop(['transaction timestamp'],axis=1)

# %%
date['timestamp']=date['timestamp              ']
date1=date.drop(['timestamp              '],axis=1)

# %%
new_df=pd.merge(df2,date1,on='timestamp')

# %%
new_df=new_df.drop_duplicates()

# %%
new_df.shape
# Out:
# (536639, 12)

# %%
import re

# %%
new_df=new_df[~new_df['transaction id'].str.startswith("C")]

# %%
new_df.shape
# Out:
# (527388, 12)

# %%
new_df1=new_df[new_df['quantity sold']>=0]

# %% [markdown]
# new_df1 is the one without negative quantity sold

# %%
new_df1['sales']=new_df1['quantity sold']*new_df1['unit price']
# Out:
# /usr/local/lib/python3.6/dist-packages/ipykernel_launcher.py:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: http://pandas.pydata.org/pandas-docs/stable/indexing.html#indexing-view-versus-copy
#   """Entry point for launching an IPython kernel.

# %%
new_df1
# Out:
#          transaction id product id  ...  time_of_day(hh:mm:ss)   sales
# 0                536365     85123A  ...               08:26:00   15.30
# 7                536365      71053  ...               08:26:00   20.34
# 14               536365     84406B  ...               08:26:00   22.00
# 21               536365     84029G  ...               08:26:00   20.34
# 28               536365     84029E  ...               08:26:00   20.34
# 35               536365      22752  ...               08:26:00   15.30
# 42               536365      21730  ...               08:26:00   25.50
# 49               536366      22633  ...               08:28:00   11.10
# 51               536366      22632  ...               08:28:00   11.10
# 53               536367      84879  ...               08:34:00   54.08
# 69               536367      22745  ...               08:34:00   12.60
# 85               536367      22748  ...               08:34:00   12.60
# 101              536367      22749  ...               08:34:00   30.00
# 117              536367      22310  ...               08:34:00    9.90
# 133              536367      84969  ...               08:34:00   25.50
# 149              536367      22623  ...               08:34:00   14.85
# 165              536367      22622  ...               08:34:00   19.90
# 181              536367      21754  ...               08:34:00   17.85
# 197              536367      21755  ...               08:34:00   17.85
# 213              536367      21777  ...               08:34:00   31.80
# 229              536367      48187  ...               08:34:00   31.80
# 245              536368      22960  ...               08:34:00   25.50
# 261              536368      22913  ...               08:34:00   14.85
# 277              536368      22912  ...               08:34:00   14.85
# 293              536368      22914  ...               08:34:00   14.85
# 309              536369      21756  ...               08:35:00   17.85
# 310              536370      22728  ...               08:45:00   90.00
# 330              536370      22727  ...               08:45:00   90.00
# 350              536370      22726  ...               08:45:00   45.00
# 370              536370      21724  ...               08:45:00   10.20
# ...                 ...        ...  ...                    ...     ...
# 61276693         581585      22726  ...               12:31:00   30.00
# 61276714         581585      22727  ...               12:31:00   15.00
# 61276735         581585      16016  ...               12:31:00    8.50
# 61276756         581585      21916  ...               12:31:00   10.08
# 61276777         581585      84692  ...               12:31:00   10.50
# 61276798         581585      84946  ...               12:31:00   15.00
# 61276819         581585      21684  ...               12:31:00   10.20
# 61276840         581585      22398  ...               12:31:00    4.68
# 61276861         581585      23328  ...               12:31:00   15.00
# 61276882         581585      23145  ...               12:31:00   11.40
# 61276903         581585      22466  ...               12:31:00   23.40
# 61276924         581586      22061  ...               12:49:00   23.60
# 61276928         581586      23275  ...               12:49:00   30.00
# 61276932         581586      21217  ...               12:49:00  214.80
# 61276936         581586      20685  ...               12:49:00   70.80
# 61276940         581587      22631  ...               12:50:00   23.40
# 61276955         581587      22556  ...               12:50:00   19.80
# 61276970         581587      22555  ...               12:50:00   19.80
# 61276985         581587      22728  ...               12:50:00   15.00
# 61277000         581587      22727  ...               12:50:00   15.00
# 61277015         581587      22726  ...               12:50:00   15.00
# 61277030         581587      22730  ...               12:50:00   15.00
# 61277045         581587      22367  ...               12:50:00   15.60
# 61277060         581587      22629  ...               12:50:00   23.40
# 61277075         581587      23256  ...               12:50:00   16.60
# 61277090         581587      22613  ...               12:50:00   10.20
# 61277105         581587      22899  ...               12:50:00   12.60
# 61277120         581587      23254  ...               12:50:00   16.60
# 61277135         581587      23255  ...               12:50:00   16.60
# 61277150         581587      22138  ...               12:50:00   14.85
#
# [526052 rows x 13 columns]

# %%
import matplotlib.pyplot as plt

# %%
df_com=new_df1.groupby('date').sum()

# %%
df_com['ddate']=new_df1['date'].drop_duplicates()

# %%
df_com
# Out:
#             quantity sold  unit price  customer id  ...     sales  date ddate
# date                                                ...
# 01/02/2011          15831     5400.14   18927427.0  ...  29013.29   NaN   NaN
# 01/03/2011          12137     6396.72   15934179.0  ...  26344.68   NaN   NaN
# 01/04/2011          18529     4474.77   16474089.0  ...  25565.64   NaN   NaN
# 01/05/2011           3814     1284.36    6730926.0  ...   6958.11   NaN   NaN
# 01/06/2011          10965     5637.23   10898529.0  ...  20585.19   NaN   NaN
# 01/07/2011           7792     3344.81   12651812.0  ...  13632.21   NaN   NaN
# 01/08/2011          11670     4353.35   15110998.0  ...  21358.64   NaN   NaN
# 01/09/2011          27851     3505.00   21297817.0  ...  37358.62   NaN   NaN
# 01/11/2011          16866     4967.24   26330931.0  ...  29091.90   NaN   NaN
# 01/12/2010          26906    12682.21   29689623.0  ...  58776.79   NaN   NaN
# 01/12/2011          27004     9867.53   32685102.0  ...  52068.63   NaN   NaN
# 02/02/2011           9709     5882.34   15539730.0  ...  21162.12   NaN   NaN
# 02/03/2011           8612     3238.37   13723042.0  ...  18669.94   NaN   NaN
# 02/06/2011          14646     6896.03   15130056.0  ...  32800.49   NaN   NaN
# 02/08/2011          15718     4827.24   12507593.0  ...  26575.55   NaN   NaN
# 02/09/2011          18905    10369.11   16533985.0  ...  42226.28   NaN   NaN
# 02/10/2011           8332     3660.75   21782114.0  ...  11531.56   NaN   NaN
# 02/11/2011          28689     9155.72   27396248.0  ...  45690.08   NaN   NaN
# 02/12/2010          31283     6536.34   31562137.0  ...  47629.42   NaN   NaN
# 02/12/2011          28718    10116.80   29607569.0  ...  57476.48   NaN   NaN
# 03/02/2011          16992     3760.55   12574718.0  ...  23467.73   NaN   NaN
# 03/03/2011          20111     5381.48   14199515.0  ...  36367.14   NaN   NaN
# 03/04/2011           5658     1712.54   11601807.0  ...   6897.18   NaN   NaN
# 03/05/2011          12594    13350.05   14853342.0  ...  35196.21   NaN   NaN
# 03/06/2011           7680     3229.56    9902827.0  ...  16895.10   NaN   NaN
# 03/07/2011           3091     1720.65    9007421.0  ...   5972.73   NaN   NaN
# 03/08/2011          16601     4718.05   20263812.0  ...  28068.20   NaN   NaN
# 03/10/2011          25960    11863.57   26234289.0  ...  66243.94   NaN   NaN
# 03/11/2011          34545     7501.31   29778354.0  ...  63425.47   NaN   NaN
# 03/12/2010          16430    11021.77   16594064.0  ...  46898.63   NaN   NaN
# ...                   ...         ...          ...  ...       ...   ...   ...
# 27/11/2011          10943     6231.96   37538986.0  ...  20279.37   NaN   NaN
# 28/01/2011          18135     3796.34    9512934.0  ...  20064.35   NaN   NaN
# 28/02/2011           9964     7933.41   14455221.0  ...  21675.29   NaN   NaN
# 28/03/2011          13485     6219.08   19369932.0  ...  23133.23   NaN   NaN
# 28/04/2011          13826     4569.43   15346280.0  ...  22490.44   NaN   NaN
# 28/06/2011          21827     4472.35   11825855.0  ...  35545.83   NaN   NaN
# 28/07/2011          30568     4802.34   19403756.0  ...  56243.32   NaN   NaN
# 28/08/2011           6701     2717.77   18000670.0  ...  10686.56   NaN   NaN
# 28/09/2011          25530     8966.01   31699623.0  ...  43693.08   NaN   NaN
# 28/10/2011          24095     4779.15   21136425.0  ...  40455.26   NaN   NaN
# 28/11/2011          29334    12638.25   41152340.0  ...  56965.73   NaN   NaN
# 29/03/2011          32916     9027.15   16538065.0  ...  70711.92   NaN   NaN
# 29/05/2011           4067     1666.73    9792091.0  ...   7338.94   NaN   NaN
# 29/06/2011          12110     4780.89    8516584.0  ...  22087.47   NaN   NaN
# 29/07/2011          11567     3547.33   13976708.0  ...  18716.54   NaN   NaN
# 29/09/2011          27665     6990.42   35026243.0  ...  46343.35   NaN   NaN
# 29/11/2011          30845    18555.47   39817789.0  ...  72384.82   NaN   NaN
# 30/01/2011           3383     2221.11   10968391.0  ...   6542.61   NaN   NaN
# 30/03/2011          21044     4935.41   19104276.0  ...  31821.71   NaN   NaN
# 30/06/2011          21949     5428.99   18528138.0  ...  44763.51   NaN   NaN
# 30/08/2011          10296    15560.03    5890968.0  ...  31837.77   NaN   NaN
# 30/09/2011          22561     6870.63   21988555.0  ...  44347.06   NaN   NaN
# 30/10/2011          19943     7426.39   42683339.0  ...  34397.95   NaN   NaN
# 30/11/2011          28500    15245.75   31526094.0  ...  60025.57   NaN   NaN
# 31/01/2011          13406     5997.70   15461639.0  ...  23628.71   NaN   NaN
# 31/03/2011          16862     8245.89   15625026.0  ...  34268.40   NaN   NaN
# 31/05/2011          11724     4976.26   14152232.0  ...  22652.61   NaN   NaN
# 31/07/2011          19413     3128.51   19068327.0  ...  33209.68   NaN   NaN
# 31/08/2011          13002     5321.84   11558605.0  ...  25367.22   NaN   NaN
# 31/10/2011          21787    18574.82   27464341.0  ...  57327.45   NaN   NaN
#
# [305 rows x 7 columns]

# %%
plt.plot(df_com['date'],df_com['sales'])
